# %% [markdown]
# # Sentiment Column Creation
# The cell below creates a new column labelled "sentiment". If the rating for a review is >3, it is considered positive and is given a sentiment value of 1. If the rating is <=3, it is considered negative and is given a sentiment value of 0. This ensures the data is prepared for Task 4 (Binary Sentiment Prediction).

# %%
import pyarrow.dataset as ds
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from pathlib import Path
import gc

input_path = Path("C:/Users/zachr/final_cleaned_Video_Games.parquet")
output_path = Path("C:/Users/zachr/sentiment_Video_Games.parquet")

# Load dataset in streaming mode
dataset = ds.dataset(input_path, format="parquet")
scanner = dataset.scanner(batch_size=50_000)

# Create a Parquet writer (to append in chunks)
writer = None

for i, batch in enumerate(scanner.to_batches()):
    df = batch.to_pandas()

    # Add sentiment column
    df["sentiment"] = df["rating"].apply(lambda r: 1 if r > 3 else 0)

    # Convert to Arrow Table
    table = pa.Table.from_pandas(df, preserve_index=True)

    if writer is None:
        # First chunk — create new file
        writer = pq.ParquetWriter(output_path, table.schema, compression="snappy")
    
    writer.write_table(table)

    print(f"✅ Processed chunk {i+1}: {len(df)} rows")

    # Cleanup
    del df
    del table
    gc.collect()

if writer:
    writer.close()

print(f"\n🎉 Saved full sentiment-augmented file to: {output_path}")
# Out:
# ✅ Processed chunk 1: 19986 rows
# ✅ Processed chunk 2: 19912 rows
# ✅ Processed chunk 3: 19769 rows
# ✅ Processed chunk 4: 19850 rows
# ✅ Processed chunk 5: 19680 rows
# ✅ Processed chunk 6: 19640 rows
# ✅ Processed chunk 7: 19775 rows
# ✅ Processed chunk 8: 19811 rows
# ✅ Processed chunk 9: 19835 rows
# ✅ Processed chunk 10: 19864 rows
# ✅ Processed chunk 11: 19811 rows
# ✅ Processed chunk 12: 19842 rows
# ✅ Processed chunk 13: 19936 rows
# ✅ Processed chunk 14: 19834 rows
# ✅ Processed chunk 15: 19855 rows
# ✅ Processed chunk 16: 19826 rows
# ✅ Processed chunk 17: 19777 rows
# ✅ Processed chunk 18: 19790 rows
# ✅ Processed chunk 19: 19754 rows
# ✅ Processed chunk 20: 19732 rows
# ✅ Processed chunk 21: 19801 rows
# ✅ Processed chunk 22: 19784 rows
# ✅ Processed chunk 23: 19750 rows
# ✅ Processed chunk 24: 19906 rows
# ✅ Processed chunk 25: 19851 rows
# ✅ Processed chunk 26: 19889 rows
# ✅ Processed chunk 27: 19879 rows
# ✅ Processed chunk 28: 19836 rows
# ✅ Processed chunk 29: 19861 rows
# ✅ Processed chunk 30: 19822 rows
# ✅ Processed chunk 31: 19794 rows
# ✅ Processed chunk 32: 19790 rows
# ✅ Processed chunk 33: 19889 rows
# ✅ Processed chunk 34: 19879 rows
# ✅ Processed chunk 35: 19960 rows
# ✅ Processed chunk 36: 19845 rows
# ✅ Processed chunk 37: 19846 rows
# ✅ Processed chunk 38: 19855 rows
# ✅ Processed chunk 39: 19816 rows
# ✅ Processed chunk 40: 19834 rows
# ✅ Processed chunk 41: 19814 rows
# ✅ Processed chunk 42: 19810 rows
# ✅ Processed chunk 43: 19797 rows
# ✅ Processed chunk 44: 19749 rows
# ✅ Processed chunk 45: 19783 rows
# ✅ Processed chunk 46: 19958 rows
# ✅ Processed chunk 47: 19884 rows
# ✅ Processed chunk 48: 19898 rows
# ✅ Processed chunk 49: 19866 rows
# ✅ Processed chunk 50: 19503 rows
# ✅ Processed chunk 51: 19674 rows
# ✅ Processed chunk 52: 19806 rows
# ✅ Processed chunk 53: 19863 rows
# ✅ Processed chunk 54: 19881 rows
# ✅ Processed chunk 55: 19888 rows
# ✅ Processed chunk 56: 19866 rows
# ✅ Processed chunk 57: 19929 rows
# ✅ Processed chunk 58: 19856 rows
# ✅ Processed chunk 59: 19682 rows
# ✅ Processed chunk 60: 19728 rows
# ✅ Processed chunk 61: 19742 rows
# ✅ Processed chunk 62: 19795 rows
# ✅ Processed chunk 63: 19864 rows
# ✅ Processed chunk 64: 19371 rows
# ✅ Processed chunk 65: 19748 rows
# ✅ Processed chunk 66: 19738 rows
# ✅ Processed chunk 67: 19746 rows
# ✅ Processed chunk 68: 19954 rows
# ✅ Processed chunk 69: 19732 rows
# ✅ Processed chunk 70: 19821 rows
# ✅ Processed chunk 71: 19795 rows
# ✅ Processed chunk 72: 19832 rows
# ✅ Processed chunk 73: 19849 rows
# ✅ Processed chunk 74: 19779 rows
# ✅ Processed chunk 75: 19785 rows
# ✅ Processed chunk 76: 19767 rows
# ✅ Processed chunk 77: 17650 rows
# ✅ Processed chunk 78: 18412 rows
# ✅ Processed chunk 79: 19944 rows
# ✅ Processed chunk 80: 19646 rows
# ✅ Processed chunk 81: 19044 rows
# ✅ Processed chunk 82: 19713 rows
# ✅ Processed chunk 83: 19241 rows
# ✅ Processed chunk 84: 19397 rows
# ✅ Processed chunk 85: 19410 rows
# ✅ Processed chunk 86: 19603 rows
# ✅ Processed chunk 87: 19548 rows
# ✅ Processed chunk 88: 19613 rows
# ✅ Processed chunk 89: 19498 rows
# ✅ Processed chunk 90: 19897 rows
# ✅ Processed chunk 91: 19493 rows
# ✅ Processed chunk 92: 19555 rows
# ✅ Processed chunk 93: 19646 rows
# ✅ Processed chunk 94: 19446 rows
# ✅ Processed chunk 95: 19343 rows
# ✅ Processed chunk 96: 19480 rows
# ✅ Processed chunk 97: 19466 rows
# ✅ Processed chunk 98: 19514 rows
# ✅ Processed chunk 99: 19675 rows
# ✅ Processed chunk 100: 19669 rows
# ✅ Processed chunk 101: 19926 rows
# ✅ Processed chunk 102: 19610 rows
# ✅ Processed chunk 103: 19670 rows
# ✅ Processed chunk 104: 19618 rows
# ✅ Processed chunk 105: 19766 rows
# ✅ Processed chunk 106: 19598 rows
# ✅ Processed chunk 107: 19570 rows
# ✅ Processed chunk 108: 19563 rows
# ✅ Processed chunk 109: 19693 rows
# ✅ Processed chunk 110: 19601 rows
# ✅ Processed chunk 111: 19767 rows
# ✅ Processed chunk 112: 19957 rows
# ✅ Processed chunk 113: 19903 rows
# ✅ Processed chunk 114: 19809 rows
# ✅ Processed chunk 115: 19878 rows
# ✅ Processed chunk 116: 19870 rows
# ✅ Processed chunk 117: 19863 rows
# ✅ Processed chunk 118: 19835 rows
# ✅ Processed chunk 119: 19124 rows
# ✅ Processed chunk 120: 19762 rows
# ✅ Processed chunk 121: 19863 rows
# ✅ Processed chunk 122: 19786 rows
# ✅ Processed chunk 123: 19631 rows
# ✅ Processed chunk 124: 19876 rows
# ✅ Processed chunk 125: 19223 rows
# ✅ Processed chunk 126: 19840 rows
# ✅ Processed chunk 127: 19858 rows
# ✅ Processed chunk 128: 19837 rows
# ✅ Processed chunk 129: 19811 rows
# ✅ Processed chunk 130: 19834 rows
# ✅ Processed chunk 131: 19838 rows
# ✅ Processed chunk 132: 19528 rows
# ✅ Processed chunk 133: 19599 rows
# ✅ Processed chunk 134: 19380 rows
# ✅ Processed chunk 135: 19925 rows
# ✅ Processed chunk 136: 19402 rows
# ✅ Processed chunk 137: 19440 rows
# ✅ Processed chunk 138: 19336 rows
# ✅ Processed chunk 139: 19217 rows
# ✅ Processed chunk 140: 19479 rows
# ✅ Processed chunk 141: 19652 rows
# ✅ Processed chunk 142: 19495 rows
# ✅ Processed chunk 143: 19605 rows
# ✅ Processed chunk 144: 18232 rows
# ✅ Processed chunk 145: 18277 rows
# ✅ Processed chunk 146: 19899 rows
# ✅ Processed chunk 147: 19358 rows
# ✅ Processed chunk 148: 19620 rows
# ✅ Processed chunk 149: 4550 rows
# ✅ Processed chunk 150: 19927 rows
# ✅ Processed chunk 151: 19940 rows
# ✅ Processed chunk 152: 19939 rows
# ✅ Processed chunk 153: 19923 rows
# ✅ Processed chunk 154: 19875 rows
# ✅ Processed chunk 155: 19927 rows
# ✅ Processed chunk 156: 19959 rows
# ✅ Processed chunk 157: 19929 rows
# ✅ Processed chunk 158: 19907 rows
# ✅ Processed chunk 159: 19927 rows
# ✅ Processed chunk 160: 19942 rows
# ✅ Processed chunk 161: 19906 rows
# ✅ Processed chunk 162: 19896 rows
# ✅ Processed chunk 163: 19839 rows
# ✅ Processed chunk 164: 19862 rows
# ✅ Processed chunk 165: 19828 rows
# ✅ Processed chunk 166: 19909 rows
# ✅ Processed chunk 167: 19977 rows
# ✅ Processed chunk 168: 19883 rows
# ✅ Processed chunk 169: 19817 rows
# ✅ Processed chunk 170: 19885 rows
# ✅ Processed chunk 171: 19888 rows
# ✅ Processed chunk 172: 19872 rows
# ✅ Processed chunk 173: 19927 rows
# ✅ Processed chunk 174: 19835 rows
# ✅ Processed chunk 175: 19927 rows
# ✅ Processed chunk 176: 19801 rows
# ✅ Processed chunk 177: 19912 rows
# ✅ Processed chunk 178: 19957 rows
# ✅ Processed chunk 179: 19895 rows
# ✅ Processed chunk 180: 19927 rows
# ✅ Processed chunk 181: 19861 rows
# ✅ Processed chunk 182: 19930 rows
# ✅ Processed chunk 183: 19859 rows
# ✅ Processed chunk 184: 19867 rows
# ✅ Processed chunk 185: 19861 rows
# ✅ Processed chunk 186: 19915 rows
# ✅ Processed chunk 187: 19851 rows
# ✅ Processed chunk 188: 19915 rows
# ✅ Processed chunk 189: 19954 rows
# ✅ Processed chunk 190: 19882 rows
# ✅ Processed chunk 191: 19917 rows
# ✅ Processed chunk 192: 19918 rows
# ✅ Processed chunk 193: 19908 rows
# ✅ Processed chunk 194: 19883 rows
# ✅ Processed chunk 195: 19930 rows
# ✅ Processed chunk 196: 19918 rows
# ✅ Processed chunk 197: 19890 rows
# ✅ Processed chunk 198: 19896 rows
# ✅ Processed chunk 199: 19860 rows
# ✅ Processed chunk 200: 19942 rows
# ✅ Processed chunk 201: 19925 rows
# ✅ Processed chunk 202: 19915 rows
# ✅ Processed chunk 203: 19890 rows
# ✅ Processed chunk 204: 19903 rows
# ✅ Processed chunk 205: 19906 rows
# ✅ Processed chunk 206: 19893 rows
# ✅ Processed chunk 207: 19855 rows
# ✅ Processed chunk 208: 19913 rows
# ✅ Processed chunk 209: 19915 rows
# ✅ Processed chunk 210: 19912 rows
# ✅ Processed chunk 211: 19823 rows
# ✅ Processed chunk 212: 19912 rows
# ✅ Processed chunk 213: 19923 rows
# ✅ Processed chunk 214: 19882 rows
# ✅ Processed chunk 215: 19801 rows
# ✅ Processed chunk 216: 19882 rows
# ✅ Processed chunk 217: 19865 rows
# ✅ Processed chunk 218: 19814 rows
# ✅ Processed chunk 219: 19861 rows
# ✅ Processed chunk 220: 19827 rows
# ✅ Processed chunk 221: 19847 rows
# ✅ Processed chunk 222: 19917 rows
# ✅ Processed chunk 223: 19565 rows
# ✅ Processed chunk 224: 19831 rows
# ✅ Processed chunk 225: 19867 rows
# ✅ Processed chunk 226: 19834 rows
# ✅ Processed chunk 227: 19877 rows
# ✅ Processed chunk 228: 19908 rows
# ✅ Processed chunk 229: 19876 rows
# ✅ Processed chunk 230: 19589 rows
# ✅ Processed chunk 231: 19833 rows
# ✅ Processed chunk 232: 19899 rows
#
# 🎉 Saved full sentiment-augmented file to: C:\Users\zachr\sentiment_Video_Games.parquet

# %% [markdown]
# # Verification Check
# Check to ensure sentiment column was added.

# %%
import pandas as pd

df = pd.read_parquet("C:/Users/zachr/sentiment_Video_Games.parquet")
df.head()
# Out:
#   parent_asin  rating                                               text  \
# 0  B07DK1H3H5     4.0  I’m playing on ps5 and it’s interesting.  It’s...
# 1  B07SRWRH5D     5.0  Nostalgic fun.  A bit slow.  I hope they don’t...
# 2  B07MFMFW34     5.0  This was an order for my kids & they have real...
# 3  B0BCHWZX95     5.0  These work great, They use batteries which is ...
# 4  B00HUWA45W     5.0  I would recommend to anyone looking to add jus...
#
#                         user_id        asin      timestamp  \
# 0  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B07DJWBYKP  1608186804795
# 1  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B00ZS80PC2  1587051114941
# 2  AGXVBIUFLFGMVLATYXHJYL4A5Q7Q  B01FEHJYUU  1490877431000
# 3  AFTC6ZR5IKNRDG5JCPVNVMU3XV2Q  B07GXJHRVK  1577637634017
# 4  AFTC6ZR5IKNRDG5JCPVNVMU3XV2Q  B00HUWA45W  1427591932000
#
#                                           categories main_category  \
# 0                       ['Video Games' 'PC' 'Games']   Video Games
# 1            ['Video Games' 'PlayStation 4' 'Games']   Video Games
# 2                       ['Video Games' 'PC' 'Games']   Video Games
# 3  ['Video Games' 'Nintendo Switch' 'Accessories'...   Video Games
# 4           ['Video Games' 'Xbox One' 'Accessories']     Computers
#
#    helpful_vote  verified_purchase  \
# 0             0               True
# 1             1              False
# 2             0               True
# 3             0               True
# 4             0               True
#
#                                              title_y  average_rating  \
# 0    Cyberpunk 2077 - PC [Game Download Code in Box]             4.1
# 1          Final Fantasy VII: Remake - PlayStation 4             4.8
# 2  Sid Meier’s Civilization VI: Rise and Fall [On...             3.0
# 3  PowerA Enhanced Wireless Controller for Ninten...             4.6
# 4    KontrolFreek FPS Freek CQC Signature - Xbox One             4.0
#
#    rating_number  price         brand  review_length  year  sentiment
# 0           2015   None   WARNER BROS             48  2020          1
# 1           9097  25.95   Square Enix             19  2020          1
# 2             31  29.99            2K             15  2017          1
# 3          19492  67.61        PowerA             39  2019          1
# 4            287   None  KontrolFreek             37  2015          1
